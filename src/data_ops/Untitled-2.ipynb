# %%
# %% Imports
import sys
from pathlib import Path

# Figure out project root (adjust depending on notebook location)
# If your notebook is in src/, then parent() is the project root
project_root = Path.cwd().parent  

# Add BOTH project root (for main.py) and src/ (for your packages)
sys.path.append(str(project_root))
sys.path.append(str(project_root / "src"))

# Import your existing modules
from main import main
from data_ops.data_visualizer import plot_single_scenario

# Make sure matplotlib plots show inline
# %matplotlib inline

# Run question 1.a
main("1.a")
# Out:
# --- Running: Question 1.a (Min Cost w/ Min Energy Target) ---
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 25 rows, 120 columns and 120 nonzeros
# Model fingerprint: 0xc964489b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-01, 3e+00]
#   Bounds range     [2e-01, 1e+03]
#   RHS range        [2e+01, 2e+01]
# Presolve removed 9 rows and 66 columns
# Presolve time: 0.01s
# Presolved: 16 rows, 54 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.0800000e+03   1.499706e+04   0.000000e+00      0s
#        5    1.4377500e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.437750000e+01
#
# ...

# %%
# %% Imports
import sys
from pathlib import Path

# Figure out project root (adjust depending on notebook location)
# If your notebook is in src/, then parent() is the project root
project_root = Path.cwd().parent  

# Add BOTH project root (for main.py) and src/ (for your packages)
sys.path.append(str(project_root))
sys.path.append(str(project_root / "src"))

# Import your existing modules
from main import main
from data_ops.data_visualizer import plot_single_scenario

# Make sure matplotlib plots show inline
# %matplotlib inline

# Run question 1.a
main("1.a")
# Out:
# --- Running: Question 1.a (Min Cost w/ Min Energy Target) ---
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 25 rows, 120 columns and 120 nonzeros
# Model fingerprint: 0xc964489b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-01, 3e+00]
#   Bounds range     [2e-01, 1e+03]
#   RHS range        [2e+01, 2e+01]
# Presolve removed 9 rows and 66 columns
# Presolve time: 0.01s
# Presolved: 16 rows, 54 columns, 69 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.0800000e+03   1.499706e+04   0.000000e+00      0s
#        5    1.4377500e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.437750000e+01
#
# ...
